# %% [markdown]
# ### 前準備
# ---

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %%
# csvファイルの読み込み
date_df = pd.read_csv('SpeedDatingData.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas/_libs/parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas/_libs/parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas/_libs/parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas/_libs/parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8e in position 17: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-54a79983385a> in <module>()
#       1 # csvファイルの読み込み
# ----> 2 date_df = pd.read_csv('SpeedDatingData.csv')
#
# ...

# %% [markdown]
# ### Error
# ---
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8e in position 17: invalid start byte
# 文字コードをshif-jisに直す必要がある

# %%
# csvファイルの読み込み
date_df = pd.read_csv('SpeedDatingData.csv', encoding="shift-jis")

# %%
date_df
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# 5       1   1.0       0    1       1     1     10         7       NaN      6
# 6       1   1.0       0    1       1     1     10         7       NaN      1
# 7       1   1.0       0    1       1     1     10         7       NaN      2
# 8       1   1.0       0    1       1     1     10         7       NaN      8
# 9       1   1.0       0    1       1     1     10         7       NaN      9
# 10      2   2.0       0    3       1     1     10         3       NaN     10
# ...

# %% [markdown]
# ### データ概要
# ---
# * データ量：　8378行(8377個のデータ)*195列

# %%
# 列名の確認
date_df.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %% [markdown]
# ### カラム概要
# ---
# 195カラムもあるやん・・・
# * iid
# * id
# * gender
# * idg
# * condtn
# * wave
# * round
# * position
# * position1
# * order
# ...
# * attr3_3
# * sinc3_3
# ...
# * amb5_3

# %%
# 基本統計量
date_df.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000
# mean     11.350919    16.872046     9.042731     9.295775     8.927668
# std       5.995903     4.358458     5.514939     5.650199     5.477009
# ...

# %% [markdown]
# #### memo
# ---
# * attr3_3より右側に行くにつれて、欠測値が増加傾向(回答数が2000個程度に減少)
# * ほぼ数値。10~22段階評価が多い？　 カテゴリ変数は無さそう

# %%
# 各列の型を確認する
date_df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-cc3e44de70b6> in <module>()
#       1 # 各列の型を確認する
# ----> 2 date_df.dtypes()
#
# TypeError: 'property' object is not callable

# %% [markdown]
# error起きてるのでskip

# %%
# 
date_df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-92fc826cdb86> in <module>()
#       1 #
# ----> 2 date_df.info()
#
# TypeError: info() missing 1 required positional argument: 'self'

# %%
# 
date_df.info('self')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-626190c49da7> in <module>()
#       1 #
# ----> 2 date_df.info('self')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    1626
#    1627         lines.append(str(type(self)))
# -> 1628         lines.append(self.index.summary())
#    1629
#    1630         if len(self.columns) == 0:
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'summary'

# %% [markdown]
# 飛ばして、可視化する

# %%
# 各メソッドについての概要をまとめよう！
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 描画したいグラフをブラウザで表示させるためのコード（要確認）
# %matplotlib inline

# %%
sns.countplot('condtn' ,data=date_df, palette='RdBu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-541c6617c0bf> in <module>()
# ----> 1 sns.countplot('condtn' ,data=date_df, palette='RdBu')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3338                           estimator, ci, n_boot, units,
#    3339                           orient, color, palette, saturation,
# -> 3340                           errcolor, errwidth, capsize, dodge)
#    3341
#    3342     plotter.value_label = "count"
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1584         """Initialize the plotter."""
# ...
